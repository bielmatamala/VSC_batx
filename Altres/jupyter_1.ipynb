# %% [markdown]
# Nombres

# %% [markdown]
# Principalment 2 tipus: enters(int), decimals(float)

# %%
a = 2 
b = 3.2222222222222222222222222222222222  
c = True
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# Opercaions aritmetiques

# %%
#Suma
print(2 + 3.2222222222222)
#Resta
print(2 - 3.2222222222222)
#Multiplicacio
print(2 * 3.2222222222222)
#Divisio
print(2 / 10)
#Divisio entera
print(1015 // 29)
#Potencia
print(2 ** 10)
#Residu divisó
print(2 % 15)
#arrel quadrada
print(2 ** (1/2))
# Out:
# 5.2222222222222
# -1.2222222222222001
# 6.4444444444444
# 0.2
# 35
# 1024
# 2
# 1.4142135623730951

# %% [markdown]
# Seguix gerarquia opercaions

# %%
#Gerarquia operacions
a = (2 + 10)**2 * 5 - 3*5 + (5/2)**2
b = (5/2)+3**-(1/2) + ((5-3)/(2))/4
print(a)
print(b)
# Out:
# 711.25
# 3.3273502691896257
# (-1+1.4142135623730951j)
